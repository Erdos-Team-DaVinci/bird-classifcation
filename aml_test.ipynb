# %% [markdown]
# ## DaVinvi team project - Erdos Institute Spring 2022
#
# The Birds 400 dataset includes 400 bird species with 58388 training images, 2000 test images and 2000 validation images. Data are available at: https://www.kaggle.com/datasets/gpiosenka/100-bird-species

# %% [markdown]
# ## EDA

# %%
# !pip install google.colab
# Out:
# Collecting google.colab
#   Downloading google-colab-1.0.0.tar.gz (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 KB 824.9 kB/s eta 0:00:00 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting google-auth~=1.4.0
#   Downloading google_auth-1.4.2-py2.py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 KB 1.7 MB/s eta 0:00:00
# Collecting ipykernel~=4.6.0
#   Downloading ipykernel-4.6.1-py3-none-any.whl (104 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.5/104.5 KB 2.5 MB/s eta 0:00:0000:01
# Collecting ipython~=5.5.0
#   Downloading ipython-5.5.0-py3-none-any.whl (758 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 758.9/758.9 KB 5.5 MB/s eta 0:00:0000:0100:01
# Collecting notebook~=5.2.0
#   Downloading notebook-5.2.2-py2.py3-none-any.whl (8.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 5.8 MB/s eta 0:00:0000:0100:01
# Collecting six~=1.12.0
#   Downloading six-1.12.0-py2.py3-none-any.whl (10 kB)
# Collecting pandas~=0.24.0
#   Downloading pandas-0.24.2.tar.gz (11.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 5.1 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Collecting portpicker~=1.2.0
#   Downloading portpicker-1.2.0.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting requests~=2.21.0
#   Downloading requests-2.21.0-py2.py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.0/58.0 KB 1.5 MB/s eta 0:00:00
# Collecting tornado~=4.5.0
#   Downloading tornado-4.5.3.tar.gz (484 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 484.2/484.2 KB 4.5 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 KB 2.6 MB/s eta 0:00:0000:01
# Collecting rsa>=3.1.4
#   Downloading rsa-4.8-py3-none-any.whl (39 kB)
# Collecting cachetools>=2.0.0
#   Downloading cachetools-5.2.0-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: jupyter-client in /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages (from ipykernel~=4.6.0->google.colab) (7.3.0)
# Requirement already satisfied: traitlets>=4.1.0 in /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages (from ipykernel~=4.6.0->google.colab) (5.1.1)
# Requirement already satisfied: setuptools>=18.5 in /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages (from ipython~=5.5.0->google.colab) (62.1.0)
# Requirement already satisfied: appnope in /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages (from ipython~=5.5.0->google.colab) (0.1.3)
# Requirement already satisfied: pickleshare in /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages (from ipython~=5.5.0->google.colab) (0.7.5)
# Requirement already satisfied: pygments in /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages (from ipython~=5.5.0->google.colab) (2.12.0)
# Collecting prompt-toolkit<2.0.0,>=1.0.4
#   Downloading prompt_toolkit-1.0.18-py3-none-any.whl (245 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.4/245.4 KB 3.5 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: pexpect in /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages (from ipython~=5.5.0->google.colab) (4.8.0)
# Collecting simplegeneric>0.8
#   Downloading simplegeneric-0.8.1.zip (12 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: decorator in /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages (from ipython~=5.5.0->google.colab) (5.1.1)
# Requirement already satisfied: jinja2 in /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages (from notebook~=5.2.0->google.colab) (3.1.1)
# Requirement already satisfied: terminado>=0.3.3 in /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages (from notebook~=5.2.0->google.colab) (0.13.3)
# Requirement already satisfied: nbconvert in /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages (from notebook~=5.2.0->google.colab) (6.4.5)
# Requirement already satisfied: ipython-genutils in /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages (from notebook~=5.2.0->google.colab) (0.2.0)
# Requirement already satisfied: nbformat in /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages (from notebook~=5.2.0->google.colab) (5.3.0)
# Requirement already satisfied: jupyter-core in /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages (from notebook~=5.2.0->google.colab) (4.9.2)
# Requirement already satisfied: python-dateutil>=2.5.0 in /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages (from pandas~=0.24.0->google.colab) (2.8.2)
# Requirement already satisfied: pytz>=2011k in /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages (from pandas~=0.24.0->google.colab) (2022.1)
# Requirement already satisfied: numpy>=1.12.0 in /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages (from pandas~=0.24.0->google.colab) (1.22.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages (from requests~=2.21.0->google.colab) (2021.10.8)
# Collecting chardet<3.1.0,>=3.0.2
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 KB 3.4 MB/s eta 0:00:0000:01
# Collecting idna<2.9,>=2.5
#   Downloading idna-2.8-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.6/58.6 KB 1.8 MB/s eta 0:00:00
# Collecting urllib3<1.25,>=1.21.1
#   Downloading urllib3-1.24.3-py2.py3-none-any.whl (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.8/118.8 KB 2.4 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: wcwidth in /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython~=5.5.0->google.colab) (0.2.5)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 KB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: ptyprocess in /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages (from terminado>=0.3.3->notebook~=5.2.0->google.colab) (0.7.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages (from jinja2->notebook~=5.2.0->google.colab) (2.1.1)
# Requirement already satisfied: entrypoints in /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages (from jupyter-client->ipykernel~=4.6.0->google.colab) (0.4)
# Requirement already satisfied: pyzmq>=22.3 in /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages (from jupyter-client->ipykernel~=4.6.0->google.colab) (22.3.0)
# Collecting jupyter-client
#   Downloading jupyter_client-7.3.1-py3-none-any.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.0/131.0 KB 2.7 MB/s eta 0:00:00a 0:00:01
#   Downloading jupyter_client-7.2.2-py3-none-any.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.6/130.6 KB 2.0 MB/s eta 0:00:00a 0:00:01
#   Downloading jupyter_client-7.2.1-py3-none-any.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.4/130.4 KB 2.1 MB/s eta 0:00:00a 0:00:01
#   Downloading jupyter_client-7.2.0-py3-none-any.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.5/130.5 KB 2.1 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: nest-asyncio>=1.5.1 in /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages (from jupyter-client->ipykernel~=4.6.0->google.colab) (1.5.5)
#   Downloading jupyter_client-7.1.2-py3-none-any.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.3/130.3 KB 2.3 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages (from nbconvert->notebook~=5.2.0->google.colab) (0.5.13)
# Requirement already satisfied: bleach in /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages (from nbconvert->notebook~=5.2.0->google.colab) (5.0.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages (from nbconvert->notebook~=5.2.0->google.colab) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages (from nbconvert->notebook~=5.2.0->google.colab) (1.5.0)
# Requirement already satisfied: testpath in /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages (from nbconvert->notebook~=5.2.0->google.colab) (0.6.0)
# Requirement already satisfied: defusedxml in /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages (from nbconvert->notebook~=5.2.0->google.colab) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages (from nbconvert->notebook~=5.2.0->google.colab) (4.11.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages (from nbconvert->notebook~=5.2.0->google.colab) (0.2.2)
# Requirement already satisfied: fastjsonschema in /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages (from nbformat->notebook~=5.2.0->google.colab) (2.15.3)
# Requirement already satisfied: jsonschema>=2.6 in /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages (from nbformat->notebook~=5.2.0->google.colab) (4.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook~=5.2.0->google.colab) (0.18.1)
# Requirement already satisfied: attrs>=17.4.0 in /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook~=5.2.0->google.colab) (21.4.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages (from beautifulsoup4->nbconvert->notebook~=5.2.0->google.colab) (2.3.1)
# Requirement already satisfied: webencodings in /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages (from bleach->nbconvert->notebook~=5.2.0->google.colab) (0.5.1)
# Building wheels for collected packages: google.colab, pandas, portpicker, tornado, simplegeneric
#   Building wheel for google.colab (setup.py) ... done
#   Created wheel for google.colab: filename=google_colab-1.0.0-py2.py3-none-any.whl size=102295 sha256=09d3fd25dde9514192a03fec7d4357e8b61ec1790f35d35ec9994b4836e669f3
#   Stored in directory: /Users/allisonlonderee/Library/Caches/pip/wheels/bf/ed/8e/5d95a614975eba0e18a249c8a3fad29524f9011bf1ced6cafa
#   Building wheel for pandas (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [1067 lines of output]
#       /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-install-h7l0hm03/pandas_f1ca337a8bf04fa4804821c6363fce6b/setup.py:435: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#         current_system = LooseVersion(platform.mac_ver()[0])
#       /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-install-h7l0hm03/pandas_f1ca337a8bf04fa4804821c6363fce6b/setup.py:436: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#         python_target = LooseVersion(
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib.macosx-11.0-arm64-cpython-310
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas
#       copying pandas/conftest.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas
#       copying pandas/_version.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas
#       copying pandas/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas
#       copying pandas/testing.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/compat
#       copying pandas/compat/chainmap_impl.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/compat
#       copying pandas/compat/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/compat
#       copying pandas/compat/chainmap.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/compat
#       copying pandas/compat/pickle_compat.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/compat
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       copying pandas/core/accessor.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       copying pandas/core/categorical.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       copying pandas/core/nanops.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       copying pandas/core/missing.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       copying pandas/core/algorithms.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       copying pandas/core/config.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       copying pandas/core/resample.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       copying pandas/core/window.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       copying pandas/core/index.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       copying pandas/core/config_init.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       copying pandas/core/generic.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       copying pandas/core/series.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       copying pandas/core/sorting.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       copying pandas/core/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       copying pandas/core/api.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       copying pandas/core/ops.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       copying pandas/core/common.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       copying pandas/core/frame.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       copying pandas/core/indexing.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       copying pandas/core/panel.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       copying pandas/core/base.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       copying pandas/core/strings.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       copying pandas/core/apply.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/util
#       copying pandas/util/_depr_module.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/util
#       copying pandas/util/_test_decorators.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/util
#       copying pandas/util/_validators.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/util
#       copying pandas/util/_print_versions.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/util
#       copying pandas/util/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/util
#       copying pandas/util/_decorators.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/util
#       copying pandas/util/_doctools.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/util
#       copying pandas/util/testing.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/util
#       copying pandas/util/_exceptions.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/util
#       copying pandas/util/_tester.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/util
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/io
#       copying pandas/io/feather_format.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io
#       copying pandas/io/parquet.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io
#       copying pandas/io/gcs.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io
#       copying pandas/io/pytables.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io
#       copying pandas/io/html.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io
#       copying pandas/io/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io
#       copying pandas/io/clipboards.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io
#       copying pandas/io/parsers.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io
#       copying pandas/io/excel.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io
#       copying pandas/io/api.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io
#       copying pandas/io/common.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io
#       copying pandas/io/date_converters.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io
#       copying pandas/io/pickle.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io
#       copying pandas/io/sql.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io
#       copying pandas/io/s3.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io
#       copying pandas/io/packers.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io
#       copying pandas/io/stata.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io
#       copying pandas/io/gbq.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/tseries
#       copying pandas/tseries/plotting.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tseries
#       copying pandas/tseries/converter.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tseries
#       copying pandas/tseries/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tseries
#       copying pandas/tseries/api.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tseries
#       copying pandas/tseries/offsets.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tseries
#       copying pandas/tseries/frequencies.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tseries
#       copying pandas/tseries/holiday.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tseries
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/tests
#       copying pandas/tests/test_expressions.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests
#       copying pandas/tests/test_register_accessor.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests
#       copying pandas/tests/test_common.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests
#       copying pandas/tests/test_downstream.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests
#       copying pandas/tests/test_errors.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests
#       copying pandas/tests/test_sorting.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests
#       copying pandas/tests/test_join.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests
#       copying pandas/tests/test_panel.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests
#       copying pandas/tests/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests
#       copying pandas/tests/test_lib.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests
#       copying pandas/tests/test_nanops.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests
#       copying pandas/tests/test_take.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests
#       copying pandas/tests/test_algos.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests
#       copying pandas/tests/test_multilevel.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests
#       copying pandas/tests/test_compat.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests
#       copying pandas/tests/test_config.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests
#       copying pandas/tests/test_window.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests
#       copying pandas/tests/test_strings.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests
#       copying pandas/tests/test_base.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/_libs
#       copying pandas/_libs/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/_libs
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/plotting
#       copying pandas/plotting/_converter.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/plotting
#       copying pandas/plotting/_tools.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/plotting
#       copying pandas/plotting/_style.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/plotting
#       copying pandas/plotting/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/plotting
#       copying pandas/plotting/_core.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/plotting
#       copying pandas/plotting/_timeseries.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/plotting
#       copying pandas/plotting/_compat.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/plotting
#       copying pandas/plotting/_misc.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/plotting
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/arrays
#       copying pandas/arrays/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/arrays
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/api
#       copying pandas/api/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/api
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/errors
#       copying pandas/errors/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/errors
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/compat/numpy
#       copying pandas/compat/numpy/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/compat/numpy
#       copying pandas/compat/numpy/function.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/compat/numpy
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/core/reshape
#       copying pandas/core/reshape/tile.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/reshape
#       copying pandas/core/reshape/merge.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/reshape
#       copying pandas/core/reshape/concat.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/reshape
#       copying pandas/core/reshape/util.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/reshape
#       copying pandas/core/reshape/reshape.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/reshape
#       copying pandas/core/reshape/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/reshape
#       copying pandas/core/reshape/api.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/reshape
#       copying pandas/core/reshape/melt.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/reshape
#       copying pandas/core/reshape/pivot.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/reshape
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/core/tools
#       copying pandas/core/tools/timedeltas.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/tools
#       copying pandas/core/tools/datetimes.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/tools
#       copying pandas/core/tools/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/tools
#       copying pandas/core/tools/numeric.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/tools
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/core/util
#       copying pandas/core/util/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/util
#       copying pandas/core/util/hashing.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/util
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/core/dtypes
#       copying pandas/core/dtypes/cast.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/dtypes
#       copying pandas/core/dtypes/missing.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/dtypes
#       copying pandas/core/dtypes/concat.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/dtypes
#       copying pandas/core/dtypes/generic.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/dtypes
#       copying pandas/core/dtypes/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/dtypes
#       copying pandas/core/dtypes/dtypes.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/dtypes
#       copying pandas/core/dtypes/api.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/dtypes
#       copying pandas/core/dtypes/common.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/dtypes
#       copying pandas/core/dtypes/inference.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/dtypes
#       copying pandas/core/dtypes/base.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/dtypes
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/core/groupby
#       copying pandas/core/groupby/categorical.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/groupby
#       copying pandas/core/groupby/generic.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/groupby
#       copying pandas/core/groupby/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/groupby
#       copying pandas/core/groupby/ops.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/groupby
#       copying pandas/core/groupby/grouper.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/groupby
#       copying pandas/core/groupby/groupby.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/groupby
#       copying pandas/core/groupby/base.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/groupby
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/core/internals
#       copying pandas/core/internals/arrays.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/internals
#       copying pandas/core/internals/concat.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/internals
#       copying pandas/core/internals/construction.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/internals
#       copying pandas/core/internals/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/internals
#       copying pandas/core/internals/blocks.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/internals
#       copying pandas/core/internals/managers.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/internals
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/core/computation
#       copying pandas/core/computation/check.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/computation
#       copying pandas/core/computation/align.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/computation
#       copying pandas/core/computation/pytables.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/computation
#       copying pandas/core/computation/engines.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/computation
#       copying pandas/core/computation/expressions.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/computation
#       copying pandas/core/computation/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/computation
#       copying pandas/core/computation/api.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/computation
#       copying pandas/core/computation/ops.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/computation
#       copying pandas/core/computation/common.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/computation
#       copying pandas/core/computation/eval.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/computation
#       copying pandas/core/computation/scope.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/computation
#       copying pandas/core/computation/expr.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/computation
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/core/arrays
#       copying pandas/core/arrays/categorical.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/arrays
#       copying pandas/core/arrays/interval.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/arrays
#       copying pandas/core/arrays/timedeltas.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/arrays
#       copying pandas/core/arrays/datetimes.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/arrays
#       copying pandas/core/arrays/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/arrays
#       copying pandas/core/arrays/numpy_.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/arrays
#       copying pandas/core/arrays/_ranges.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/arrays
#       copying pandas/core/arrays/integer.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/arrays
#       copying pandas/core/arrays/period.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/arrays
#       copying pandas/core/arrays/sparse.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/arrays
#       copying pandas/core/arrays/datetimelike.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/arrays
#       copying pandas/core/arrays/array_.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/arrays
#       copying pandas/core/arrays/base.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/arrays
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/core/sparse
#       copying pandas/core/sparse/scipy_sparse.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/sparse
#       copying pandas/core/sparse/series.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/sparse
#       copying pandas/core/sparse/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/sparse
#       copying pandas/core/sparse/api.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/sparse
#       copying pandas/core/sparse/frame.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/sparse
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/core/indexes
#       copying pandas/core/indexes/accessors.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/indexes
#       copying pandas/core/indexes/interval.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/indexes
#       copying pandas/core/indexes/timedeltas.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/indexes
#       copying pandas/core/indexes/range.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/indexes
#       copying pandas/core/indexes/datetimes.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/indexes
#       copying pandas/core/indexes/multi.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/indexes
#       copying pandas/core/indexes/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/indexes
#       copying pandas/core/indexes/api.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/indexes
#       copying pandas/core/indexes/period.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/indexes
#       copying pandas/core/indexes/frozen.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/indexes
#       copying pandas/core/indexes/numeric.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/indexes
#       copying pandas/core/indexes/datetimelike.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/indexes
#       copying pandas/core/indexes/base.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/indexes
#       copying pandas/core/indexes/category.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/indexes
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/io/msgpack
#       copying pandas/io/msgpack/_version.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/msgpack
#       copying pandas/io/msgpack/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/msgpack
#       copying pandas/io/msgpack/exceptions.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/msgpack
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/io/formats
#       copying pandas/io/formats/console.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/formats
#       copying pandas/io/formats/style.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/formats
#       copying pandas/io/formats/terminal.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/formats
#       copying pandas/io/formats/html.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/formats
#       copying pandas/io/formats/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/formats
#       copying pandas/io/formats/format.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/formats
#       copying pandas/io/formats/excel.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/formats
#       copying pandas/io/formats/css.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/formats
#       copying pandas/io/formats/csvs.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/formats
#       copying pandas/io/formats/latex.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/formats
#       copying pandas/io/formats/printing.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/formats
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/io/json
#       copying pandas/io/json/normalize.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/json
#       copying pandas/io/json/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/json
#       copying pandas/io/json/table_schema.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/json
#       copying pandas/io/json/json.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/json
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/io/sas
#       copying pandas/io/sas/sas7bdat.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/sas
#       copying pandas/io/sas/sas_constants.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/sas
#       copying pandas/io/sas/sasreader.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/sas
#       copying pandas/io/sas/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/sas
#       copying pandas/io/sas/sas_xport.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/sas
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/io/clipboard
#       copying pandas/io/clipboard/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/clipboard
#       copying pandas/io/clipboard/clipboards.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/clipboard
#       copying pandas/io/clipboard/exceptions.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/clipboard
#       copying pandas/io/clipboard/windows.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/clipboard
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       copying pandas/tests/series/test_block_internals.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       copying pandas/tests/series/test_alter_axes.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       copying pandas/tests/series/test_period.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       copying pandas/tests/series/conftest.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       copying pandas/tests/series/test_timeseries.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       copying pandas/tests/series/test_constructors.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       copying pandas/tests/series/test_missing.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       copying pandas/tests/series/test_sorting.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       copying pandas/tests/series/test_timezones.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       copying pandas/tests/series/test_operators.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       copying pandas/tests/series/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       copying pandas/tests/series/test_subclass.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       copying pandas/tests/series/test_analytics.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       copying pandas/tests/series/test_io.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       copying pandas/tests/series/test_apply.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       copying pandas/tests/series/test_quantile.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       copying pandas/tests/series/test_datetime_values.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       copying pandas/tests/series/test_internals.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       copying pandas/tests/series/common.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       copying pandas/tests/series/test_repr.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       copying pandas/tests/series/test_validate.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       copying pandas/tests/series/test_duplicates.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       copying pandas/tests/series/test_asof.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       copying pandas/tests/series/test_api.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       copying pandas/tests/series/test_rank.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       copying pandas/tests/series/test_arithmetic.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       copying pandas/tests/series/test_replace.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       copying pandas/tests/series/test_combine_concat.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       copying pandas/tests/series/test_dtypes.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/reshape
#       copying pandas/tests/reshape/test_cut.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/reshape
#       copying pandas/tests/reshape/test_union_categoricals.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/reshape
#       copying pandas/tests/reshape/test_qcut.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/reshape
#       copying pandas/tests/reshape/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/reshape
#       copying pandas/tests/reshape/test_pivot.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/reshape
#       copying pandas/tests/reshape/test_reshape.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/reshape
#       copying pandas/tests/reshape/test_util.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/reshape
#       copying pandas/tests/reshape/test_melt.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/reshape
#       copying pandas/tests/reshape/test_concat.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/reshape
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/tools
#       copying pandas/tests/tools/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/tools
#       copying pandas/tests/tools/test_numeric.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/tools
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/extension
#       copying pandas/tests/extension/test_external_block.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/extension
#       copying pandas/tests/extension/test_period.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/extension
#       copying pandas/tests/extension/conftest.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/extension
#       copying pandas/tests/extension/test_common.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/extension
#       copying pandas/tests/extension/test_sparse.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/extension
#       copying pandas/tests/extension/test_categorical.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/extension
#       copying pandas/tests/extension/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/extension
#       copying pandas/tests/extension/test_interval.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/extension
#       copying pandas/tests/extension/test_datetime.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/extension
#       copying pandas/tests/extension/test_integer.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/extension
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/resample
#       copying pandas/tests/resample/conftest.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/resample
#       copying pandas/tests/resample/test_resampler_grouper.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/resample
#       copying pandas/tests/resample/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/resample
#       copying pandas/tests/resample/test_timedelta.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/resample
#       copying pandas/tests/resample/test_period_index.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/resample
#       copying pandas/tests/resample/test_datetime_index.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/resample
#       copying pandas/tests/resample/test_base.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/resample
#       copying pandas/tests/resample/test_time_grouper.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/resample
#       copying pandas/tests/resample/test_resample_api.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/resample
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/util
#       copying pandas/tests/util/test_validate_args_and_kwargs.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/util
#       copying pandas/tests/util/test_assert_series_equal.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/util
#       copying pandas/tests/util/conftest.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/util
#       copying pandas/tests/util/test_safe_import.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/util
#       copying pandas/tests/util/test_locale.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/util
#       copying pandas/tests/util/test_assert_frame_equal.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/util
#       copying pandas/tests/util/test_assert_interval_array_equal.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/util
#       copying pandas/tests/util/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/util
#       copying pandas/tests/util/test_util.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/util
#       copying pandas/tests/util/test_move.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/util
#       copying pandas/tests/util/test_assert_index_equal.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/util
#       copying pandas/tests/util/test_validate_args.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/util
#       copying pandas/tests/util/test_validate_kwargs.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/util
#       copying pandas/tests/util/test_assert_categorical_equal.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/util
#       copying pandas/tests/util/test_assert_numpy_array_equal.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/util
#       copying pandas/tests/util/test_assert_extension_array_equal.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/util
#       copying pandas/tests/util/test_deprecate.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/util
#       copying pandas/tests/util/test_hashing.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/util
#       copying pandas/tests/util/test_deprecate_kwarg.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/util
#       copying pandas/tests/util/test_assert_almost_equal.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/util
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/io
#       copying pandas/tests/io/test_parquet.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/io
#       copying pandas/tests/io/test_compression.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/io
#       copying pandas/tests/io/test_date_converters.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/io
#       copying pandas/tests/io/conftest.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/io
#       copying pandas/tests/io/test_common.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/io
#       copying pandas/tests/io/test_pickle.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/io
#       copying pandas/tests/io/test_clipboard.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/io
#       copying pandas/tests/io/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/io
#       copying pandas/tests/io/test_stata.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/io
#       copying pandas/tests/io/test_html.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/io
#       copying pandas/tests/io/test_pytables.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/io
#       copying pandas/tests/io/test_gcs.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/io
#       copying pandas/tests/io/test_sql.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/io
#       copying pandas/tests/io/test_gbq.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/io
#       copying pandas/tests/io/test_feather.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/io
#       copying pandas/tests/io/generate_legacy_storage_files.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/io
#       copying pandas/tests/io/test_excel.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/io
#       copying pandas/tests/io/test_s3.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/io
#       copying pandas/tests/io/test_packers.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/io
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/tseries
#       copying pandas/tests/tseries/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/tseries
#       copying pandas/tests/tseries/test_frequencies.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/tseries
#       copying pandas/tests/tseries/test_holiday.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/tseries
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/frame
#       copying pandas/tests/frame/test_block_internals.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/frame
#       copying pandas/tests/frame/test_alter_axes.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/frame
#       copying pandas/tests/frame/test_period.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/frame
# ...
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/_libs/tslibs/timedeltas.pyi
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/_libs/tslibs/timedeltas.pyi
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/_libs/tslibs/timedeltas.pyx
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/_libs/tslibs/timedeltas.pyx
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/_libs/tslibs/timestamps.pxd
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/_libs/tslibs/timestamps.pxd
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/_libs/tslibs/timestamps.pyi
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/_libs/tslibs/timestamps.pyi
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/_libs/tslibs/timestamps.pyx
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/_libs/tslibs/timestamps.pyx
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/_libs/tslibs/timezones.pxd
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/_libs/tslibs/timezones.pxd
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/_libs/tslibs/timezones.pyi
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/_libs/tslibs/timezones.pyi
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/_libs/tslibs/timezones.pyx
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/_libs/tslibs/timezones.pyx
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/_libs/tslibs/tzconversion.pxd
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/_libs/tslibs/tzconversion.pxd
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/_libs/tslibs/tzconversion.pyi
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/_libs/tslibs/tzconversion.pyi
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/_libs/tslibs/tzconversion.pyx
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/_libs/tslibs/tzconversion.pyx
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/_libs/tslibs/util.pxd
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/_libs/tslibs/util.pxd
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/_libs/tslibs/vectorized.pyi
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/_libs/tslibs/vectorized.pyi
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/_libs/tslibs/vectorized.pyx
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/_libs/tslibs/vectorized.pyx
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/_libs/util.pxd
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/_libs/util.pxd
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/_libs/window/__init__.py
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/_libs/window/__init__.py
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/_libs/window/__pycache__/
#    from /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/_libs/window/~_pycache__
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/_libs/window/aggregations.pyi
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/_libs/window/aggregations.pyi
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/_libs/window/aggregations.pyx
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/_libs/window/aggregations.pyx
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/_libs/window/indexers.pyi
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/_libs/window/indexers.pyi
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/_libs/window/indexers.pyx
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/_libs/window/indexers.pyx
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/_libs/writers.pyi
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/_libs/writers.pyi
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/_libs/writers.pyx
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/_libs/writers.pyx
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/_testing/
#    from /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/~testing
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/_typing.py
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/_typing.py
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/_version.py
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/_version.py
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/api/
#    from /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/~pi
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/arrays/
#    from /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/~rrays
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/compat/
#    from /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/~ompat
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/conftest.py
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/conftest.py
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/core/
#    from /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/~ore
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/errors/
#    from /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/~rrors
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/io/__init__.py
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/io/__init__.py
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/io/__pycache__/
#    from /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/io/~_pycache__
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/io/api.py
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/io/api.py
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/io/clipboard/
#    from /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/io/~lipboard
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/io/clipboards.py
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/io/clipboards.py
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/io/common.py
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/io/common.py
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/io/date_converters.py
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/io/date_converters.py
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/io/excel/
#    from /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/io/~xcel
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/io/feather_format.py
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/io/feather_format.py
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/io/formats/
#    from /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/io/~ormats
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/io/gbq.py
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/io/gbq.py
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/io/html.py
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/io/html.py
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/io/json/
#    from /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/io/~son
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/io/orc.py
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/io/orc.py
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/io/parquet.py
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/io/parquet.py
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/io/parsers/
#    from /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/io/~arsers
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/io/pickle.py
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/io/pickle.py
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/io/pytables.py
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/io/pytables.py
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/io/sas/__init__.py
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/io/sas/__init__.py
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/io/sas/__pycache__/
#    from /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/io/sas/~_pycache__
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/io/sas/sas.pyx
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/io/sas/sas.pyx
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/io/sas/sas7bdat.py
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/io/sas/sas7bdat.py
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/io/sas/sas_constants.py
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/io/sas/sas_constants.py
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/io/sas/sas_xport.py
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/io/sas/sas_xport.py
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/io/sas/sasreader.py
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/io/sas/sasreader.py
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/io/spss.py
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/io/spss.py
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/io/sql.py
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/io/sql.py
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/io/stata.py
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/io/stata.py
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/io/xml.py
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/io/xml.py
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/plotting/
#    from /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/~lotting
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/testing.py
#    from /private/var/folders/8v/kmqwjstx6sv9d9t9mh2qqpvw0000gn/T/pip-uninstall-anri23ol/testing.py
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/tests/
#    from /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/~ests
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/tseries/
#    from /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/~series
#   Moving to /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/util/
#    from /opt/homebrew/Caskroom/miniforge/base/envs/erdos_bootcamp_2022/lib/python3.10/site-packages/pandas/~til
# error: legacy-install-failure
#
# × Encountered error while trying to install package.
# ╰─> pandas
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [5], in <cell line: 7>()
#       3 import pandas as pd
#       4 import matplotlib.pyplot as plt
# ----> 7 from google.colab import drive
#       8 drive.mount('/content/gdrive')
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
from google.colab import files

files.upload()
# Out:
#      <input type="file" id="files-f219ee95-e218-4f74-92ea-f64bf17cb2ab" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f219ee95-e218-4f74-92ea-f64bf17cb2ab">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-aac4dfaac8e9> in <module>()
#       1 from google.colab import files
#       2
# ----> 3 files.upload()
#
# /usr/local/lib/python3.7/dist-packages/google/colab/files.py in upload()
#      44   """
#      45
# ---> 46   uploaded_files = _upload_files(multiple=True)
#      47   # Mapping from original filename to filename as saved locally.
#      48   local_filenames = dict()
#
# /usr/local/lib/python3.7/dist-packages/google/colab/files.py in _upload_files(multiple)
#     127     result = _output.eval_js(
#     128         'google.colab._files._uploadFilesContinue("{output_id}")'.format(
# --> 129             output_id=output_id))
#     130     if result['action'] != 'append':
#     131       # JS side uses a generator of promises to process all of the files- some
#
# /usr/local/lib/python3.7/dist-packages/google/colab/output/_js.py in eval_js(script, ignore_result, timeout_sec)
#      38   if ignore_result:
#      39     return
# ---> 40   return _message.read_reply_from_input(request_id, timeout_sec)
#      41
#      42
#
# /usr/local/lib/python3.7/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#      99     reply = _read_next_input_message()
#     100     if reply == _NOT_READY or not isinstance(reply, dict):
# --> 101       time.sleep(0.025)
#     102       continue
#     103     if (reply.get('type') == 'colab_reply' and
#
# KeyboardInterrupt:

# %%
! mkdir ~/.kaggle
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
 ! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! mkdir  '/content/gdrive'
# Out:
# mkdir: cannot create directory ‘/content/gdrive/data’: Operation not supported

# %%
! kaggle datasets list -s 'BIRDS 400'
# Out:
# ref                                     title                                     size  lastUpdated          downloadCount  voteCount  usabilityRating
# --------------------------------------  ----------------------------------------  ----  -------------------  -------------  ---------  ---------------
# gpiosenka/100-bird-species              BIRDS 400 - SPECIES IMAGE CLASSIFICATION   1GB  2022-02-17 15:49:59          26219        769  0.85294116
# akimball002/hummingbirds-at-my-feeders  Hummingbirds at my feeders                20MB  2020-06-19 22:41:06             59          7  0.8125
# nigarkhasayeva/bbirds-400               bbirds_400                                 1GB  2022-03-29 01:55:35              0          0  0.11764706

# %%
# !kaggle datasets download -d 'gpiosenka/100-bird-species' -p /content/kaggle/
# Out:
# Downloading 100-bird-species.zip to /content/kaggle
#  99% 1.48G/1.49G [00:18<00:00, 114MB/s]
# 100% 1.49G/1.49G [00:18<00:00, 84.7MB/s]

# %%
! ls
# Out:
#  birds.csv		       'images to test'		       test
# 'birds latin names.csv'         kaggle			       train
#  class_dict.csv		        kaggle.json		       valid
#  EfficientNetB4-BIRDS-0.99.h5   my_csv-2-17-2022-1-17-48.csv
#  gdrive			        sample_data

# %%
train =  "train/"
train_dic = {}
for name in os.listdir(train):
    if os.path.isdir(os.path.join(train, name)):
        train_dic[name] = len([i for i in os.listdir(os.path.join(train, name))])
# print(train)


plt.figure(figsize=(20, 10))
plt.bar(range(len(train_dic)), list(train_dic.values()), align='center')
plt.xticks(range(len(train_dic)))
plt.xlabel('Label index')
plt.ylabel('Count')
plt.title('Label distribution')
plt.show()

# %%
# !cp -r valid/E* valid10/

# %%
# !mkdir valid10

# %%
# Importing all necessary libraries
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras import layers
from keras import backend as K

# %%
train_data_dir = 'train10/'
validation_data_dir = 'valid10/'
nb_train_samples =sum([len(files) for r, d, files in os.walk(train_data_dir)])
nb_validation_samples = sum([len(files) for r, d, files in os.walk(validation_data_dir )])
epochs = 10
batch_size = 32

# %%
## we first make an empty model
## Sequential means we'll make a group
## of a linear stack of layers
model = Sequential()

# %%
## adding our first convolutional layer

## Conv2D(32, specifies that we want a convolutional layer with depth 32
## (3,3) is our sliding grid size
## We're using the relu activation function
## and our images are a gray scale value for 28X28 pixels, hence the input_shape
model.add( layers.Conv2D( 32, (3,3), activation='relu', input_shape=(224,224,3,)  ) )


## adding our first Max Pooling layer
## MaxPooling2D((2,2) tells python we want to add
## a max pooling layer that uses a (2,2) square grid
## strides = 2, sets the stride value to 2
model.add( layers.MaxPooling2D( (2,2), strides = 2 ) )


## Add another layer, alternating between conv and pool
model.add( layers.Conv2D(64, (3,3), activation='relu'))
model.add( layers.MaxPooling2D( (2,2), strides=2) )

# %%
## Now we'll add the fully connected layer

## .Flatten() will flatten the data for us,
## meaning the last output data will turn into 
## a vector
model.add( layers.Flatten() )

## We've seen these before
## Then we add a single dense hidden layer
## This is 64 nodes high
model.add(layers.Dense(64, activation='relu'))


## Finally an output layer
#this needs to be the same as the number of classes
model.add(layers.Dense(17, activation='softmax'))

# %%
## We've seen this before in the last notebook
model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)
 
test_datagen = ImageDataGenerator(rescale=1. / 255)
 
train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode="categorical")
 
validation_generator = test_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode="categorical")
 
history = model.fit_generator(
    train_generator,
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=nb_validation_samples // batch_size)
# Out:
# Found 2353 images belonging to 17 classes.
# Found 85 images belonging to 17 classes.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:26: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/10
# 73/73 [==============================] - 178s 2s/step - loss: 3.4413 - accuracy: 0.1710 - val_loss: 1.7197 - val_accuracy: 0.4531
# Epoch 2/10
# 73/73 [==============================] - 175s 2s/step - loss: 1.7108 - accuracy: 0.4791 - val_loss: 1.1304 - val_accuracy: 0.6875
# Epoch 3/10
# 73/73 [==============================] - 175s 2s/step - loss: 1.2204 - accuracy: 0.6458 - val_loss: 0.7258 - val_accuracy: 0.7656
# Epoch 4/10
# 73/73 [==============================] - 175s 2s/step - loss: 0.9371 - accuracy: 0.7316 - val_loss: 0.6274 - val_accuracy: 0.8125
# Epoch 5/10
# 73/73 [==============================] - 174s 2s/step - loss: 0.8102 - accuracy: 0.7643 - val_loss: 0.5642 - val_accuracy: 0.8594
# Epoch 6/10
# 73/73 [==============================] - 174s 2s/step - loss: 0.6386 - accuracy: 0.8040 - val_loss: 0.6705 - val_accuracy: 0.8125
# Epoch 7/10
# 73/73 [==============================] - 173s 2s/step - loss: 0.5769 - accuracy: 0.8328 - val_loss: 0.3801 - val_accuracy: 0.8750
# Epoch 8/10
# 73/73 [==============================] - 173s 2s/step - loss: 0.4794 - accuracy: 0.8630 - val_loss: 0.3431 - val_accuracy: 0.8750
# Epoch 9/10
# 73/73 [==============================] - 173s 2s/step - loss: 0.4014 - accuracy: 0.8768 - val_loss: 0.5404 - val_accuracy: 0.8281
# Epoch 10/10
# 73/73 [==============================] - 173s 2s/step - loss: 0.3822 - accuracy: 0.8845 - val_loss: 0.4625 - val_accuracy: 0.8594

# %%
history_dict = history.history

# %%
print(history_dict.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.figure(figsize = (14,6))

plt.scatter(range(1,n_epochs+1), history_dict['accuracy'], label = "Training Accuracy")
plt.scatter(range(1,n_epochs+1), history_dict['val_accuracy'], marker='v', label = "Validation Set Accuracy")

plt.xlabel("Epoch", fontsize=18)
plt.ylabel("Accuracy", fontsize=18)

plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

plt.legend(fontsize=18)

plt.show()


plt.figure(figsize = (14,6))

plt.scatter(range(1,n_epochs+1), history_dict['loss'], label = "Training Loss")
plt.scatter(range(1,n_epochs+1), history_dict['val_loss'], marker='v', label = "Validation Set Loss")

plt.xlabel("Epoch", fontsize=18)
plt.ylabel("Loss Function Value", fontsize=18)

plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

plt.legend(fontsize=18)

plt.show()
